# %%
# !pip install pydicom
# !pip install chart_studio
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f4/15/df16546bc59bfca390cf072d473fb2c8acd4231636f64356593a63137e55/pydicom-2.1.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 3.8MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.1.2
# Collecting chart_studio
#   Downloading https://files.pythonhosted.org/packages/ca/ce/330794a6b6ca4b9182c38fc69dd2a9cbff60fd49421cb8648ee5fee352dc/chart_studio-1.1.0-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 2.7MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart_studio) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart_studio) (4.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2020.12.5)
# Installing collected packages: chart-studio
# Successfully installed chart-studio-1.1.0

# %%
# !mkdir AllResults_HGSR
# !mkdir result_files_HGSR
# !mkdir Model_HGSR

# %%
import numpy as np
import os, sys, stat
import copy
from math import *
import matplotlib.pyplot as plt
from functools import reduce
# reading in dicom files
import pydicom
# skimage image processing packages
# from skimage import measure, morphology
# from skimage.morphology import ball, binary_closing
# from skimage.measure import label, regionprops
# scipy linear algebra functions
# from scipy.linalg import norm
import scipy.ndimage
# ipywidgets for some interactive plots
from ipywidgets.widgets import *
import ipywidgets as widgets
# plotly 3D interactive graphs
import plotly
from plotly.graph_objs import *
import chart_studio.plotly as py
import cv2
import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.optimizers import RMSprop
import scipy.misc
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import concatenate, Add
from keras import backend as K
import math
import imageio
from contextlib import redirect_stdout
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
from keras.layers.core import Dropout, Lambda


# Set some parameters
IMG_WIDTH = 480
IMG_HEIGHT = 480
IMG_CHANNELS = 3

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2),padding='same') (c1)

c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(3, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 480, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 480, 480, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 480, 480, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 480, 480, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 480, 480, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 240, 240, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 240, 240, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 240, 240, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 120, 120, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 120, 120, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 60, 60, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 60, 60, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 30, 30, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 30, 30, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 30, 30, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 60, 60, 128)  131200      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 60, 60, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 60, 60, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 60, 60, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 60, 60, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 120, 120, 64) 32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 120, 120, 128 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 120, 120, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 120, 120, 64) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 120, 120, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 240, 240, 32) 8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 240, 240, 64) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 240, 240, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 240, 240, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 240, 240, 32) 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 480, 480, 16) 2064        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 480, 480, 32) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 480, 480, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 480, 480, 16) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 480, 480, 16) 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 480, 480, 3)  51          conv2d_17[0][0]
# ==================================================================================================
# Total params: 1,941,139
# Trainable params: 1,941,139
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def test(model):
    z = range(0, 18)
    sliced_z = 18
    test_T1 = "/content/drive/MyDrive/d2 new/test/T2"
    test_T2 = "/content/drive/MyDrive/d2 new/test/T1"
    folder_3 = os.listdir(test_T1)
    folder_4 = os.listdir(test_T2)
    T1_test_matrix = []
    T2_test_matrix = []
    T1x_test_images = []
    T2x_test_images = []
    T1y_test_images = []
    T2y_test_images = []

    for f in folder_3:
        T1xx_images = np.zeros([480,480,18]) 
        T1yx_images = np.zeros([480,480,18]) 
        temp = np.zeros([480,480,18])
        path = test_T1 + '/' + f
        slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
        slices.sort(key=lambda x: int(x.ImagePositionPatient[2]))
       
        pixel_spacing = slices[0].PixelSpacing   
        slice_thickness = slices[0].SliceThickness

        # print(pixel_spacing)
        # print(slice_thickness)
    
        image_shape = list(slices[0].pixel_array.shape)
        image_shape.append(len(slices))

        volume3d = np.zeros([480,480,18])
    
        for i,s in enumerate(slices):
            array2d = s.pixel_array
            resized_img = resize(array2d, (480, 480), anti_aliasing=True)
            volume3d[:,:,i] = resized_img
        a = volume3d
        
        temp[3:, 3:, :] = a[3:480, 3:480, z]
        a = temp
        for k in range(sliced_z):
          T1xx_images[:,:,k]=cv2.Sobel(a[:,:,k],cv2.CV_64F,1,0,ksize=5)
          T1yx_images[:,:,k]=cv2.Sobel(a[:,:,k],cv2.CV_64F,0,1,ksize=5)
        T1xx_images = np.asarray(T1xx_images)
        T1yx_images = np.asarray(T1yx_images)
        img_vol_min = np.min(a)
        img_vol_max = np.max(a)
        img_vol_x_min = np.min(T1xx_images)
        img_vol_x_max = np.max(T1xx_images)
        img_vol_y_min = np.min(T1yx_images)
        img_vol_y_max = np.max(T1yx_images)

        a = (a - img_vol_min) / (img_vol_max - img_vol_min)
        # T1xx_images = (T1xx_images - img_vol_x_min) / (img_vol_x_max - img_vol_x_min)
        # T1yx_images = (T1yx_images - img_vol_y_min) / (img_vol_y_max - img_vol_y_min)

        for some in range(sliced_z):
            T1_test_matrix.append(a[:, :, some])
            T1x_test_images.append(T1xx_images[:, :, some])
            T1y_test_images.append(T1yx_images[:, :, some])
            # del(T1xx_images)
            # del(T1yx_images)
            
            
    for f in folder_4:
        T2xx_images = np.zeros([480,480,18]) 
        T2yx_images = np.zeros([480,480,18]) 
        temp = np.zeros([480,480,18])
        path = test_T2 + '/' + f
        slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
        slices.sort(key=lambda x: int(x.ImagePositionPatient[2]))
        pixel_spacing = slices[0].PixelSpacing   
        slice_thickness = slices[0].SliceThickness

        # print(pixel_spacing)
        # print(slice_thickness)
    
        image_shape = list(slices[0].pixel_array.shape)
        image_shape.append(len(slices))
        volume3d = np.zeros([480,480,18])
        # volume3d = np.zeros(image_shape)
    
        for i,s in enumerate(slices):
            array2d = s.pixel_array
            resized_img = resize(array2d, (480, 480), anti_aliasing=True)
            volume3d[:,:,i] = resized_img
        b = volume3d
        temp[3:, 3:, :] = b[3:480, 3:480, z]
        b = temp
        for k in range(sliced_z):
          T2xx_images[:,:,k]=cv2.Sobel(b[:,:,k],cv2.CV_64F,1,0,ksize=5)
          T2yx_images[:,:,k]=cv2.Sobel(b[:,:,k],cv2.CV_64F,0,1,ksize=5)

        T2xx_images = np.asarray(T2xx_images)
        T2yx_images = np.asarray(T2yx_images)
        img_vol_min = np.min(b)
        img_vol_max = np.max(b)
        img_vol_x_min = np.min(T2xx_images)
        img_vol_x_max = np.max(T2xx_images)
        img_vol_y_min = np.min(T2yx_images)
        img_vol_y_max = np.max(T2yx_images)
        
        b = (b - img_vol_min) / (img_vol_max - img_vol_min)
        # T2xx_images = (T2xx_images - img_vol_x_min) / (img_vol_x_max - img_vol_x_min)
        # T2yx_images = (T2yx_images - img_vol_y_min) / (img_vol_y_max - img_vol_y_min)

        for some in range(sliced_z):
            T2_test_matrix.append(b[:, :, some])
            T2x_test_images.append(T2xx_images[:, :, some])
            T2y_test_images.append(T2yx_images[:, :, some])

        del(T2xx_images)
        del(T2yx_images)

    print("read both T1_test and T2_test")

    # T1_test_matrix.shape (51 * number of sucjects in T1_registered, 259, 259)
    T1_test_matrix = np.asarray(T1_test_matrix)
    # T2_test_matrix.shape (51 * number of sucjects in ground_T2, 259, 259)
    T2_test_matrix = np.asarray(T2_test_matrix)
    # T1x_test_images.shape (51 * number of sucjects in T1_registered, 259, 259)
    T1x_test_images = np.asarray(T1x_test_images)
    # T2x_images.shape (51 * number of sucjects in ground_T2, 259, 259)
    T2x_test_images = np.asarray(T2x_test_images)
    # T1y_images.shape (51 * number of sucjects in T1_registered, 259, 259)
    T1y_test_images = np.asarray(T1y_test_images)
    # T2y_images.shape (51 * number of sucjects in ground_T2, 259, 259)
    T2y_test_images = np.asarray(T2y_test_images)

    T1_test_data = np.zeros(shape=[(T1_test_matrix.shape[0]), (T1_test_matrix.shape[1]), (T1_test_matrix.shape[2]), (3)])
    T2_ground_truth = np.zeros(shape=[(T1_test_matrix.shape[0]), (T1_test_matrix.shape[1]), (T1_test_matrix.shape[2]), (3)])

    # resizeTo = 256
    for i in range(T1_test_matrix.shape[0]):
        T1_test_data[i, :, :, 0] = T1_test_matrix[i, :, :]
        T1_test_data[i, :, :, 1] = T1x_test_images[i, :, :]
        T1_test_data[i, :, :, 2] = T1y_test_images[i, :, :]
        T2_ground_truth[i, :, :, 0] = T2_test_matrix[i, :, :]
        T2_ground_truth[i, :, :, 1] = T2x_test_images[i, :, :]
        T2_ground_truth[i, :, :, 2] = T2y_test_images[i, :, :]

    del(T1_test_matrix)
    del(T1x_test_images)
    del(T1y_test_images)
    del(T2_test_matrix)
    del(T2x_test_images)
    del(T2y_test_images)
    print("made all the augmented images")

    # values less than a particular value has been made 0
    z, x, y = np.where(T1_test_data[:, :, :, 0] < 0.1)
    T1_test_data[z, x, y, 0] = 0
    z, x, y = np.where(T2_ground_truth[:, :, :, 0] < 0.1)
    T2_ground_truth[z, x, y, 0] = 0
    z, x, y = np.where(T1_test_data[:, :, :, 1] < 0.001)
    T1_test_data[z, x, y, 1] = 0
    z, x, y = np.where(T2_ground_truth[:, :, :, 1] < 0.001)
    T2_ground_truth[z, x, y, 1] = 0
    z, x, y = np.where(T1_test_data[:, :, :, 2] < 0.001)
    T1_test_data[z, x, y, 2] = 0
    z, x, y = np.where(T2_ground_truth[:, :, :, 2] < 0.001)
    T2_ground_truth[z, x, y, 2] = 0

    T1_test_data, T2_ground_truth = shuffle(T1_test_data, T2_ground_truth, random_state=2)

    myfile_test_psnr_T2_0 = open('/content/result_files_HGSR/test_psnrT2_0.txt', 'a')
    myfile_test_mse_T2_0 = open('/content/result_files_HGSR/test_mseT2_0.txt', 'a')
    myfile_test_mae_T2_0 = open('/content/result_files_HGSR/test_maeT2_0.txt', 'a')

    myfile_test_psnr_T2_1 = open('/content/result_files_HGSR/test_psnrT2_1.txt', 'a')
    myfile_test_mse_T2_1 = open('/content/result_files_HGSR/test_mseT2_1.txt', 'a')
    myfile_test_mae_T2_1 = open('/content/result_files_HGSR/test_maeT2_1.txt', 'a')

    myfile_test_psnr_T2_2 = open('/content/result_files_HGSR/test_psnrT2_2.txt', 'a')
    myfile_test_mse_T2_2 = open('/content/result_files_HGSR/test_mseT2_2.txt', 'a')
    myfile_test_mae_T2_2 = open('/content/result_files_HGSR/test_maeT2_2.txt', 'a')

    test_all_imgs_mse_file = open('/content/result_files_HGSR/test_all_imgs_mse_file.txt', 'a')
    test_all_imgs_mae_file = open('/content/result_files_HGSR/test_all_imgs_mae_file.txt', 'a')
    test_all_imgs_psnr_file = open('/content/result_files_HGSR/test_all_imgs_psnr_file.txt', 'a')

    decoded_imgs = model.predict(T1_test_data)

# edit 3
    mse_T2_0 = np.mean((T2_ground_truth[:, :, :, 0] - decoded_imgs[:, :, :, 0]) ** 2)
    check_T2_0 = math.sqrt(mse_T2_0)
    psnr_T2_0 = 20 * math.log10(1.0 / check_T2_0)
    mae_T2_0 = np.mean(np.abs((T2_ground_truth[:, :, :, 0] - decoded_imgs[:, :, :, 0])))

    mse_T2_1 = np.mean(
        (T2_ground_truth[:, :, :, 1] - decoded_imgs[:, :, :, 1]) ** 2)
    check_T2_1 = math.sqrt(mse_T2_1)
    psnr_T2_1 = 20 * math.log10(1.0 / check_T2_1)
    mae_T2_1 = np.mean(np.abs((T2_ground_truth[:, :, :, 1] - decoded_imgs[:, :, :, 1])))

    mse_T2_2 = np.mean((T2_ground_truth[:, :, :, 2] - decoded_imgs[:, :, :, 2]) ** 2)
    check_T2_2 = math.sqrt(mse_T2_2)
    psnr_T2_2 = 20 * math.log10(1.0 / check_T2_2)
    mae_T2_2 = np.mean(np.abs((T2_ground_truth[:, :, :, 2] - decoded_imgs[:, :, :, 2])))

    myfile_test_psnr_T2_0.write("%f \n" % (psnr_T2_0))
    myfile_test_mse_T2_0.write("%f \n" % (mse_T2_0))
    myfile_test_mae_T2_0.write("%f \n" % (mae_T2_0))

    myfile_test_psnr_T2_1.write("%f \n" % (psnr_T2_1))
    myfile_test_mse_T2_1.write("%f \n" % (mse_T2_1))
    myfile_test_mae_T2_1.write("%f \n" % (mae_T2_1))

    myfile_test_psnr_T2_2.write("%f \n" % (psnr_T2_2))
    myfile_test_mse_T2_2.write("%f \n" % (mse_T2_2))
    myfile_test_mae_T2_2.write("%f \n" % (mae_T2_2))

    test_all_imgs_mse = np.mean((T2_ground_truth - decoded_imgs) ** 2)
    test_all_imgs_mae = np.mean(np.abs(T2_ground_truth - decoded_imgs))
    check = math.sqrt(test_all_imgs_mse)
    test_all_imgs_psnr = 20 * math.log10(1.0 / check)
    print("mse of all images in test set is")
    print(test_all_imgs_mse)
    print("mae of all images in test set is")
    print(test_all_imgs_mae)
    print("psnr of all images in test set is")
    print(test_all_imgs_psnr)

    test_all_imgs_mse_file.write("%f \n" % test_all_imgs_mse)
    test_all_imgs_mae_file.write("%f \n" % test_all_imgs_mae)
    test_all_imgs_psnr_file.write("%f \n" % test_all_imgs_psnr)

    resizeTo = 480
    temp = np.zeros([1440, 1440])
    print("Shape of T1_test_data")
    print(T1_test_data.shape)
    print(type(T1_test_data))
    print("Shape of temp")
    print(temp.shape)
    print(type(temp))
    temp[:480, :480] = T1_test_data[0, :, :, 0]
    temp[480:480*2, :480] = T1_test_data[0, :, :, 1]
    temp[resizeTo*2:, :resizeTo] = T1_test_data[0, :, :, 2]
    temp[:resizeTo, resizeTo:resizeTo*2] = T2_ground_truth[0, :, :, 0]
    temp[resizeTo:resizeTo*2, resizeTo:resizeTo*2] = T2_ground_truth[0, :, :, 1]
    temp[resizeTo*2:, resizeTo:resizeTo*2] = T2_ground_truth[0, :, :, 2]
    temp[:resizeTo, 2*resizeTo:] = decoded_imgs[0, :, :, 0]
    temp[resizeTo:resizeTo*2, 2*resizeTo:] = decoded_imgs[0, :, :, 1]
    temp[resizeTo*2:, 2*resizeTo:] = decoded_imgs[0, :, :, 2]
    temp = temp * 480
    # scipy.misc.imsave('results_sliced_4layers_custom_loss/' + str(jj) + '.jpg', temp)
    imageio.imwrite('/content/AllResults_HGSR/test' + '.jpg', temp.astype(np.uint8))
    
    myfile_test_psnr_T2_0.close()
    myfile_test_mse_T2_0.close()
    myfile_test_mae_T2_0.close()

    myfile_test_psnr_T2_1.close()
    myfile_test_mse_T2_1.close()
    myfile_test_mae_T2_1.close()

    myfile_test_psnr_T2_2.close()
    myfile_test_mse_T2_2.close()
    myfile_test_mae_T2_2.close()

    test_all_imgs_mse_file.close()
    test_all_imgs_mae_file.close()
    test_all_imgs_psnr_file.close()

i_s = 480
# input_shape = Input(shape = (480, 480, 3))#tensor called input_shape is done
# gen = gen(input_shape)
# proSR = net2(input_shape)
# output = Add()([gen,proSR])
# model = Model(input_shape, output)
# #model.load_weights("Model_HGSR/model_epoch_295.h5") #for loading the saved weights, prefix this line before compiling
# model.compile(loss=root_mean_sq_GxGy, optimizer = RMSprop())
#print(model.summary())
#os.chmod("E:/FYP DATA/hourglass_sr.txt", stat.S_IwRITE)
 
with open('/content/hourglass_sr.txt', 'w') as f:
    with redirect_stdout(f):
        model.summary()

#x, y = 256, 256

z = range(0,18)
sliced_z = 18


#resizeTo = 259
#batch_size = 8
#inChannel = outChannel = 3

train_T1 = "/content/drive/MyDrive/d2 new/train/T2"
train_T2 = "/content/drive/MyDrive/d2 new/train/T1"
folder_1 = os.listdir(train_T1)
folder_2 = os.listdir(train_T2)


T1_train_matrix = []
T2_train_matrix = []
T1x_images = []
T2x_images = []
T1y_images = []
T2y_images = []


for f in folder_1:
    path = train_T1 + '/' + f
    T1xx_images = np.zeros([480,480,18])    
    T1yx_images = np.zeros([480,480,18])
    
    temp = np.zeros([480,480,18])    
    slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key=lambda x: int(x.ImagePositionPatient[2]))
    pixel_spacing = slices[0].PixelSpacing   
    slice_thickness = slices[0].SliceThickness

    # print(pixel_spacing)
    # print(slice_thickness)
    
    image_shape = list(slices[0].pixel_array.shape)
    image_shape.append(len(slices))

    volume3d = np.zeros([480,480,18])
    
    for i,s in enumerate(slices):
        array2d = s.pixel_array
        resized_img = resize(array2d, (480, 480), anti_aliasing=True)
        volume3d[:,:,i] = resized_img
    a = volume3d
    temp[3:, 3:, :] = a[3:480, 3:480, z]
    a = temp
    print(a.shape)
    
    for k in range(sliced_z):
        T1xx_images[:,:,k]=cv2.Sobel(a[:,:,k],cv2.CV_64F,1,0,ksize=5)
        T1yx_images[:,:,k]=cv2.Sobel(a[:,:,k],cv2.CV_64F,0,1,ksize=5)
    T1xx_images=np.asarray(T1xx_images)
    # print('after 549 line t1xx')
    print(T1xx_images.shape)
    T1yx_images=np.asarray(T1yx_images)
    img_vol_min = np.min(a)
    img_vol_max = np.max(a)
    img_vol_x_min = np.min(T1xx_images)
    img_vol_x_max = np.max(T1xx_images)
    img_vol_y_min = np.min(T1yx_images)
    img_vol_y_max = np.max(T1yx_images)

    #Volume normaization of each image.
    a = (a - img_vol_min) / (img_vol_max - img_vol_min)
#    print('a shape')
    print(a.shape)
    #a.shape == (img_row, slices, img_col : 259, 51, 259)
    # T1xx_images = (T1xx_images - img_vol_x_min) / (img_vol_x_max - img_vol_x_min)
    # print('txx shape')
    # print(T1xx_images.shape)#T1xx_images.shape = (slices, img_row, img_col : 51, 259, 259)
    # T1yx_images = (T1yx_images - img_vol_y_min) / (img_vol_y_max - img_vol_y_min) #T1yx_images.shape = (slices, img_row, img_col : 51, 259, 259)
    
    for some in range(sliced_z):
        T1_train_matrix.append(a[:,:,some]) #T1_train_matrix.shape is made into (51, 259, 259) from a.shape which was (259, 51, 259)
        T1x_images.append(T1xx_images[:, :, some])
        T1y_images.append(T1yx_images[:, :, some])
        #All there arrays have same shape (51, 259, 259)
    
    # del(T1xx_images)
    # del(T1yx_images)
    
    
for f in folder_2:
    path = train_T2 + '/' + f
    T2xx_images = np.zeros([480,480,18])  
    T2yx_images = np.zeros([480,480,18])  
    
    temp = np.zeros([480,480,18])
    slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key=lambda x: int(x.ImagePositionPatient[2]))
    pixel_spacing = slices[0].PixelSpacing   
    slice_thickness = slices[0].SliceThickness

    # print(pixel_spacing)
    # print(slice_thickness)
    
    image_shape = list(slices[0].pixel_array.shape)
    image_shape.append(len(slices))
    volume3d = np.zeros([480,480,18])
    # volume3d = np.zeros(image_shape)
    
    for i,s in enumerate(slices):
        array2d = s.pixel_array
        resized_img = resize(array2d, (480, 480), anti_aliasing=True)
        volume3d[:,:,i] = resized_img
    b = volume3d
    
    temp[3:, 3:, :] = b[3:480, 3:480, z]
    b = temp
    
    for k in range(sliced_z):
        T2xx_images[:,:,k]=cv2.Sobel(b[:,:,k],cv2.CV_64F,1,0,ksize=5)
        T2yx_images[:,:,k]=cv2.Sobel(b[:,:,k],cv2.CV_64F,0,1,ksize=5)
    T2xx_images=np.asarray(T2xx_images)
    T2yx_images=np.asarray(T2yx_images)
    img_vol_min = np.min(b)
    img_vol_max = np.max(b)
    img_vol_x_min = np.min(T2xx_images)
    img_vol_x_max = np.max(T2xx_images)
    img_vol_y_min = np.min(T2yx_images)
    img_vol_y_max = np.max(T2yx_images)

    #Volume normaization of each image.
    b = (b - img_vol_min) / (img_vol_max - img_vol_min)
    # T2xx_images = (T2xx_images - img_vol_x_min) / (img_vol_x_max - img_vol_x_min)
    # T2yx_images = (T2yx_images - img_vol_y_min) / (img_vol_y_max - img_vol_y_min)
    
    for some in range(sliced_z):
        T2_train_matrix.append(b[:,:,some])
        T2x_images.append(T2xx_images[:, :, some])
        T2y_images.append(T2yx_images[:, :, some])
    
    del(T2xx_images)
    del(T2yx_images)

print("read both ground and input")


#T1_train_matrix = np.zeros([])
T1_train_matrix = np.asarray(T1_train_matrix) #T1_train_matrix.shape (51 * number of sucjects in T1_registered, 259, 259)
T2_train_matrix = np.asarray(T2_train_matrix) #T2_train_matrix.shape (51 * number of sucjects in ground_T2, 259, 259)
T1x_images = np.asarray(T1x_images) #T1x_images.shape (51 * number of sucjects in T1_registered, 259, 259)
T2x_images = np.asarray(T2x_images) #T2x_images.shape (51 * number of sucjects in ground_T2, 259, 259)
T1y_images = np.asarray(T1y_images) #T1y_images.shape (51 * number of sucjects in T1_registered, 259, 259)
T2y_images = np.asarray(T2y_images) #T2y_images.shape (51 * number of sucjects in ground_T2, 259, 259)


data=np.zeros(shape=[(T1_train_matrix.shape[0]),(T1_train_matrix.shape[1]),(T1_train_matrix.shape[2]),(3)])
Label=np.zeros(shape=[(T1_train_matrix.shape[0]),(T1_train_matrix.shape[1]),(T1_train_matrix.shape[2]),(3)])
#data will have shape (51 * number of subjects in T1_registered, 259, 259, 3 (for image, its x gradient, its y gradient))
#Label will have shape (51 * number of subjects in ground_T2, 259, 259, 3 (for image, its x gradient, its y gradient))

#resizeTo = 256
for i in range(T1_train_matrix.shape[0]):
    data[i,:,:,0] = T1_train_matrix[i,:,:]
    data[i,:,:,1] = T1x_images[i,:,:]
    data[i,:,:,2] = T1y_images[i,:,:]
    Label[i,:,:,0] = T2_train_matrix[i,:,:]
    Label[i,:,:,1] = T2x_images[i,:,:]
    Label[i,:,:,2] = T2y_images[i,:,:]
    
del(T1_train_matrix)
del(T1x_images)
del(T1y_images)
del(T2_train_matrix)
del(T2x_images)
del(T2y_images)
print("made all the augmented images")

#values less than a particular value has been made 0
z,x,y=np.where(data[:,:,:,0]<0.1)    
data[z,x,y,0]=0
z,x,y=np.where(Label[:,:,:,0]<0.1)    
Label[z,x,y,0]=0
z,x,y=np.where(data[:,:,:,1]<0.001)    
data[z,x,y,1]=0
z,x,y=np.where(Label[:,:,:,1]<0.001)    
Label[z,x,y,1]=0
z,x,y=np.where(data[:,:,:,2]<0.001)    
data[z,x,y,2]=0
z,x,y=np.where(Label[:,:,:,2]<0.001)    
Label[z,x,y,2]=0

data, Label = shuffle(data, Label, random_state=2)
print(data.shape)
print('printing label shape below')
print(Label.shape)
train_T1, validation_T1, train_T2, validation_T2 = train_test_split(data, Label, test_size=0.2, random_state=2)

print("Training and Testing data has now following shapes")
print(train_T1.shape)
print(validation_T1.shape)

#del(data)
del(Label)

print("Training data lenth is : ", len(train_T1))

validation_T1 = np.array(validation_T1)

validation_T2 = np.array(validation_T2)

train_T1 = np.array(train_T1)
train_T2 = np.array(train_T2)

resizeTo = 480

numEpochs = 250
batch_size = 2


for jj in range(0,numEpochs):
    print("Running epoch : %d" % jj)
    myfile_valid_psnr_T2_0 = open('/content/result_files_HGSR/validation_psnrT2_0.txt', 'w+')
    myfile_valid_mse_T2_0 = open('/content/result_files_HGSR/validation_mseT2_0.txt', 'a+')
    myfile_valid_psnr_dat_T2_0 = open('/content/result_files_HGSR/validation_psnrT2_0.dat', 'a+')   #can be removed
    myfile_valid_mse_dat_T2_0 = open('/content/result_files_HGSR/validation_mseT2_0.dat', 'a+')
    myfile_valid_mae_T2_0 = open('/content/result_files_HGSR/validation_maeT2_0.txt', 'a+')
    
    myfile_valid_psnr_T1_0 = open('/content/result_files_HGSR/validation_psnrT1_0.txt', 'a+')
    myfile_valid_mse_T1_0 = open('/content/result_files_HGSR/validation_mseT1_0.txt', 'a+')
    myfile_valid_psnr_dat_T1_0 = open('/content/result_files_HGSR/validation_psnrT1_0.dat', 'a+')
    myfile_valid_mse_dat_T1_0 = open('/content/result_files_HGSR/validation_mseT1_0.dat', 'a+')

    myfile_valid_psnr_T2_1 = open('/content/result_files_HGSR/validation_psnrT2_1.txt', 'a+')
    myfile_valid_mse_T2_1 = open('/content/result_files_HGSR/validation_mseT2_1.txt', 'a+')
    myfile_valid_psnr_dat_T2_1 = open('/content/result_files_HGSR/validation_psnrT2_1.dat', 'a+')
    myfile_valid_mse_dat_T2_1 = open('/content/result_files_HGSR/validation_mseT2_1.dat', 'a+')
    myfile_valid_mae_T2_1 = open('/content/result_files_HGSR/validation_maeT2_1.txt', 'a+')
    
    myfile_valid_psnr_T1_1 = open('/content/result_files_HGSR/validation_psnrT1_1.txt', 'a+')
    myfile_valid_mse_T1_1 = open('/content/result_files_HGSR/validation_mseT1_1.txt', 'a+')
    myfile_valid_psnr_dat_T1_1 = open('/content/result_files_HGSR/validation_psnrT1_1.dat', 'a+')
    myfile_valid_mse_dat_T1_1 = open('/content/result_files_HGSR/validation_mseT1_1.dat', 'a+')

    myfile_valid_psnr_T2_2 = open('/content/result_files_HGSR/validation_psnrT2_2.txt', 'a+')
    myfile_valid_mse_T2_2 = open('/content/result_files_HGSR/validation_mseT2_2.txt', 'a+')
    myfile_valid_psnr_dat_T2_2 = open('/content/result_files_HGSR/validation_psnrT2_2.dat', 'a+')
    myfile_valid_mse_dat_T2_2 = open('/content/result_files_HGSR/validation_mseT2_2.dat', 'a+')
    myfile_valid_mae_T2_2 = open('/content/result_files_HGSR/validation_maeT2_2.txt', 'a+')
    
    myfile_valid_psnr_T1_2 = open('/content/result_files_HGSR/validation_psnrT1_2.txt', 'a+')
    myfile_valid_mse_T1_2 = open('/content/result_files_HGSR/validation_mseT1_2.txt', 'a+')
    myfile_valid_psnr_dat_T1_2 = open('/content/result_files_HGSR/validation_psnrT1_2.dat', 'a+')
    myfile_valid_mse_dat_T1_2 = open('/content/result_files_HGSR/validation_mseT1_2.dat', 'a+')

    batch_loss_file = open('/content/result_files_HGSR/batch_loss_file.txt', 'a+')
    valid_all_imgs_mse_file = open('/content/result_files_HGSR/valid_all_imgs_mse_file.txt', 'a+')
    valid_all_imgs_mae_file = open('/content/result_files_HGSR/valid_all_imgs_mae_file.txt', 'a+')
    valid_all_imgs_psnr_file = open('/content/result_files_HGSR/valid_all_imgs_psnr_file.txt', 'a+')
    train_T1, train_T2 = shuffle(train_T1, train_T2)
    num_batches = int(len(train_T1)/batch_size)
    # num_batches = 15
    for batch in range(num_batches):

        batch_train_X = train_T1[batch*batch_size:min((batch+1)*batch_size,len(train_T1)),:]
        batch_train_Y = train_T2[batch*batch_size:min((batch+1)*batch_size,len(train_T2)),:]
        
        loss = model.train_on_batch(batch_train_X,batch_train_Y)
        #print ('epoch_num: %d batch_num: %d loss: %f\n' % (jj,batch,loss))
        #batch_loss_file.write("%d %d %f\n" % (jj, batch, loss))

    #default_loss.append(loss)
    model.save_weights("/content/Model_HGSR/last_model.h5")
    if jj > 290:
        model.save_weights("/content/Model_HGSR/model_epoch_"+ str(jj) +".h5")
    #validation_T1,validation_T2 = shuffle(validation_T1,validation_T2)
    #validation_loss = autoencoder.test_on_batch(X_test,y_test)
    print("The shape is")
    decoded_imgs = model.predict(validation_T1)
    imageio.imwrite("decoded.png", decoded_imgs[0,:,:,0].astype(np.uint8))
    print(decoded_imgs.shape)
    print(validation_T2[:,:,:,0].shape)

    mse_T2_0 =  np.mean((validation_T2[:,:,:,0] - decoded_imgs[:,:,:,0]) ** 2)
    check_T2_0 = math.sqrt(mse_T2_0)
    psnr_T2_0 = 20 * math.log10( 1.0 / check_T2_0)
    mae_T2_0 = np.mean(np.abs((validation_T2[:,:,:,0] - decoded_imgs[:,:,:,0])))




    mse_T1_0=  np.mean((validation_T1[:,:,:,0] - decoded_imgs[:,:,:,0]) ** 2)
    check_T1_0 = math.sqrt(mse_T1_0)
    psnr_T1_0 = 20 * math.log10( 1.0 / check_T1_0)

    mse_T2_1=  np.mean((validation_T2[:,:,:,1] - decoded_imgs[:,:,:,1]) ** 2)
    check_T2_1 = math.sqrt(mse_T2_1)
    psnr_T2_1 = 20 * math.log10( 1.0 / check_T2_1)
    mse_T1_1 =  np.mean((validation_T1[:,:,:,1] - decoded_imgs[:,:,:,1]) ** 2)
    check_T1_1 = math.sqrt(mse_T1_1)
    psnr_T1_1 = 20 * math.log10( 1.0 / check_T1_1)
    mae_T2_1 = np.mean(np.abs((validation_T2[:,:,:,1] - decoded_imgs[:,:,:,1])))

    mse_T2_2 =  np.mean((validation_T2[:,:,:,2] - decoded_imgs[:,:,:,2]) ** 2)
    check_T2_2 = math.sqrt(mse_T2_2)
    psnr_T2_2 = 20 * math.log10( 1.0 / check_T2_2)
    mse_T1_2 =  np.mean((validation_T1[:,:,:,2] - decoded_imgs[:,:,:,2]) ** 2)
    check_T1_2 = math.sqrt(mse_T1_2)
    psnr_T1_2 = 20 * math.log10( 1.0 / check_T1_2)
    mae_T2_2 = np.mean(np.abs((validation_T2[:,:,:,2] - decoded_imgs[:,:,:,2])))

    myfile_valid_psnr_T2_0.write("%f \n" % (psnr_T2_0))
    myfile_valid_mse_T2_0.write("%f \n" % (mse_T2_0))
    myfile_valid_psnr_dat_T2_0.write("%f \n" % (psnr_T2_0))
    myfile_valid_mse_dat_T2_0.write("%f \n" % (mse_T2_0))
    myfile_valid_mae_T2_0.write("%f \n" %(mae_T2_0))

    myfile_valid_psnr_T1_0.write("%f \n" % (psnr_T1_0))
    myfile_valid_mse_T1_0.write("%f \n" % (mse_T1_0))
    myfile_valid_psnr_dat_T1_0.write("%f \n" % (psnr_T1_0))
    myfile_valid_mse_dat_T1_0.write("%f \n" % (mse_T1_0))
    
    myfile_valid_psnr_T2_1.write("%f \n" % (psnr_T2_1))
    myfile_valid_mse_T2_1.write("%f \n" % (mse_T2_1))
    myfile_valid_psnr_dat_T2_1.write("%f \n" % (psnr_T2_1))
    myfile_valid_mse_dat_T2_1.write("%f \n" % (mse_T2_1))
    myfile_valid_mae_T2_1.write("%f \n" %(mae_T2_1))
        
    myfile_valid_psnr_T1_1.write("%f \n" % (psnr_T1_1))
    myfile_valid_mse_T1_1.write("%f \n" % (mse_T1_1))
    myfile_valid_psnr_dat_T1_1.write("%f \n" % (psnr_T1_1))
    myfile_valid_mse_dat_T1_1.write("%f \n" % (mse_T1_1))
    
    myfile_valid_psnr_T2_2.write("%f \n" % (psnr_T2_2))
    myfile_valid_mse_T2_2.write("%f \n" % (mse_T2_2))
    myfile_valid_psnr_dat_T2_2.write("%f \n" % (psnr_T2_2))
    myfile_valid_mse_dat_T2_2.write("%f \n" % (mse_T2_2))
    myfile_valid_mae_T2_2.write("%f \n" %(mae_T2_2))
        
    myfile_valid_psnr_T1_2.write("%f \n" % (psnr_T1_2))
    myfile_valid_mse_T1_2.write("%f \n" % (mse_T1_2))
    myfile_valid_psnr_dat_T1_2.write("%f \n" % (psnr_T1_2))
    myfile_valid_mse_dat_T1_2.write("%f \n" % (mse_T1_2))
    
    
    #scipy.misc.imsave('results_test/' +  'decoded.jpg', 255*decoded_imgs[0,:,:,0])
    valid_all_imgs_mse = np.mean((validation_T2 - decoded_imgs) ** 2)
    valid_all_imgs_mae = np.mean(np.abs(validation_T2 - decoded_imgs))
    check = math.sqrt(valid_all_imgs_mse)
    valid_all_imgs_psnr = 20 * math.log10( 1.0 / check)
    print("mse of all images in validation set is")
    print(valid_all_imgs_mse)
    print("mae of all images in validation set is")
    print(valid_all_imgs_mae)
    print("psnr of all images in validation set is")
    print(valid_all_imgs_psnr)
    
    valid_all_imgs_mse_file.write("%f \n" % valid_all_imgs_mse)
    valid_all_imgs_mae_file.write("%f \n" % valid_all_imgs_mae)
    valid_all_imgs_psnr_file.write("%f \n" % valid_all_imgs_psnr)
 #decoded is predicted images
    #if jj % 5 == 0:
    temp = np.zeros([resizeTo*3,resizeTo*3])  #zeros
    temp[:resizeTo,:resizeTo] = validation_T1[0,:,:,0]   #full image 
    temp[resizeTo:resizeTo*2,:resizeTo] = validation_T1[0,:,:,1]  #
    temp[resizeTo*2:,:resizeTo] = validation_T1[0,:,:,2]
    temp[:resizeTo,resizeTo:resizeTo*2] = validation_T2[0,:,:,0]
    temp[resizeTo:resizeTo*2,resizeTo:resizeTo*2] = validation_T2[0,:,:,1]
    temp[resizeTo*2:,resizeTo:resizeTo*2] = validation_T2[0,:,:,2]
    temp[:resizeTo,2*resizeTo:] = decoded_imgs[0,:,:,0]
    temp[resizeTo:resizeTo*2,2*resizeTo:] = decoded_imgs[0,:,:,1]
    temp[resizeTo*2:,2*resizeTo:] = decoded_imgs[0,:,:,2]
    temp = temp * 480
        #scipy.misc.imsave('results_sliced_4layers_custom_loss/' + str(jj) + '.jpg', temp)
        
    imageio.imwrite('/content/AllResults_HGSR/recon_epoch' + str(jj) + '.jpg', temp.astype(np.uint8))
        
    #jj +=1

    myfile_valid_psnr_T2_0.close()
    myfile_valid_mse_T2_0.close()
    myfile_valid_psnr_dat_T2_0.close()
    myfile_valid_mse_dat_T2_0.close()
    myfile_valid_mae_T2_0.close()

    myfile_valid_psnr_T1_0.close()
    myfile_valid_mse_T1_0.close()
    myfile_valid_psnr_dat_T1_0.close()
    myfile_valid_mse_dat_T1_0.close()

    
    myfile_valid_psnr_T2_1.close()
    myfile_valid_mse_T2_1.close()
    myfile_valid_psnr_dat_T2_1.close()
    myfile_valid_mse_dat_T2_1.close()
    myfile_valid_mae_T2_1.close()

    myfile_valid_psnr_T1_1.close()
    myfile_valid_mse_T1_1.close()
    myfile_valid_psnr_dat_T1_1.close()
    myfile_valid_mse_dat_T1_1.close()
    
    
    myfile_valid_psnr_T2_2.close()
    myfile_valid_mse_T2_2.close()
    myfile_valid_psnr_dat_T2_2.close()
    myfile_valid_mse_dat_T2_2.close()
    myfile_valid_mae_T2_2.close()

    myfile_valid_psnr_T1_2.close()
    myfile_valid_mse_T1_2.close()
    myfile_valid_psnr_dat_T1_2.close()
    myfile_valid_mse_dat_T1_2.close()

    valid_all_imgs_mse_file.close()
    valid_all_imgs_mae_file.close()
    valid_all_imgs_psnr_file.close()
    batch_loss_file.close()

test(model)
# model.save('colabmodel.h5')
# Out:
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# (480, 480, 18)
# read both ground and input
# made all the augmented images
# (54, 480, 480, 3)
# printing label shape below
# (54, 480, 480, 3)
# Training and Testing data has now following shapes
# (43, 480, 480, 3)
# (11, 480, 480, 3)
# Training data lenth is :  43
# Running epoch : 0
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.023120788502364764
# mae of all images in validation set is
# 0.12839671826319402
# psnr of all images in validation set is
# 16.359973589891098
# Running epoch : 1
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.008733395932908894
# mae of all images in validation set is
# 0.05874230272363136
# psnr of all images in validation set is
# 20.588168504358556
# Running epoch : 2
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.006389303533965726
# mae of all images in validation set is
# 0.04587983708346667
# psnr of all images in validation set is
# 21.945464795317978
# Running epoch : 3
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.006211493264431985
# mae of all images in validation set is
# 0.04424428138435782
# psnr of all images in validation set is
# 22.06803981378366
# Running epoch : 4
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005738161036413254
# mae of all images in validation set is
# 0.040349184623549875
# psnr of all images in validation set is
# 22.412272678285547
# Running epoch : 5
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005308810139655669
# mae of all images in validation set is
# 0.03607258797039545
# psnr of all images in validation set is
# 22.750028061665265
# Running epoch : 6
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005148646221229318
# mae of all images in validation set is
# 0.033649634992047726
# psnr of all images in validation set is
# 22.883069488110394
# Running epoch : 7
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005442434564432563
# mae of all images in validation set is
# 0.03729675082575383
# psnr of all images in validation set is
# 22.6420678387193
# Running epoch : 8
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005053976110412588
# mae of all images in validation set is
# 0.031658745921975026
# psnr of all images in validation set is
# 22.963668152733476
# Running epoch : 9
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005296467313711826
# mae of all images in validation set is
# 0.036073758710665677
# psnr of all images in validation set is
# 22.760137035508414
# Running epoch : 10
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0050777912981448655
# mae of all images in validation set is
# 0.03194200231314653
# psnr of all images in validation set is
# 22.94325152994923
# Running epoch : 11
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005031360022502775
# mae of all images in validation set is
# 0.032384976510441824
# psnr of all images in validation set is
# 22.983146053154545
# Running epoch : 12
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0051630398128104235
# mae of all images in validation set is
# 0.03574215602709778
# psnr of all images in validation set is
# 22.870945260437686
# Running epoch : 13
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.004966537628073133
# mae of all images in validation set is
# 0.032244054526759845
# psnr of all images in validation set is
# 23.03946269826274
# Running epoch : 14
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00487011474041691
# mae of all images in validation set is
# 0.030184779546504652
# psnr of all images in validation set is
# 23.12460806641034
# Running epoch : 15
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.004854749565221371
# mae of all images in validation set is
# 0.032880998211964343
# psnr of all images in validation set is
# 23.13833168484642
# Running epoch : 16
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005018345747269248
# mae of all images in validation set is
# 0.02882662026496425
# psnr of all images in validation set is
# 22.99439420550619
# Running epoch : 17
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.004764418283967745
# mae of all images in validation set is
# 0.032416638694172654
# psnr of all images in validation set is
# 23.21990117373007
# Running epoch : 18
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0044749849868540486
# mae of all images in validation set is
# 0.029678323805412923
# psnr of all images in validation set is
# 23.49208417362009
# Running epoch : 19
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0045432522940753485
# mae of all images in validation set is
# 0.03096698361233294
# psnr of all images in validation set is
# 23.426331454476703
# Running epoch : 20
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.005450361491142212
# mae of all images in validation set is
# 0.03925379888463434
# psnr of all images in validation set is
# 22.63574692511988
# Running epoch : 21
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.004371653364340525
# mae of all images in validation set is
# 0.028388897000328952
# psnr of all images in validation set is
# 23.59354281288287
# Running epoch : 22
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0037492895755233888
# mae of all images in validation set is
# 0.029744922414247216
# psnr of all images in validation set is
# 24.260510156480105
# Running epoch : 23
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0035372341573373873
# mae of all images in validation set is
# 0.022654982101185682
# psnr of all images in validation set is
# 24.513361898676024
# Running epoch : 24
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.003391443409093729
# mae of all images in validation set is
# 0.02393310532878794
# psnr of all images in validation set is
# 24.69615425340333
# Running epoch : 25
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.003285807712734776
# mae of all images in validation set is
# 0.025303136429868884
# psnr of all images in validation set is
# 24.83357855308043
# Running epoch : 26
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.003182202833689823
# mae of all images in validation set is
# 0.022902462359025558
# psnr of all images in validation set is
# 24.97272141865817
# Running epoch : 27
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0027332105463580016
# mae of all images in validation set is
# 0.0202035534219175
# psnr of all images in validation set is
# 25.633269121787343
# Running epoch : 28
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0028288339291451968
# mae of all images in validation set is
# 0.02026517234337075
# psnr of all images in validation set is
# 25.483925476907174
# Running epoch : 29
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0026893010539235877
# mae of all images in validation set is
# 0.019720258177462445
# psnr of all images in validation set is
# 25.703605779405848
# Running epoch : 30
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002767092489859815
# mae of all images in validation set is
# 0.01942419225159942
# psnr of all images in validation set is
# 25.579763243558176
# Running epoch : 31
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002731560007452117
# mae of all images in validation set is
# 0.02054647246704746
# psnr of all images in validation set is
# 25.635892543772698
# Running epoch : 32
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0026926001750266484
# mae of all images in validation set is
# 0.019236246258109695
# psnr of all images in validation set is
# 25.698281303133594
# Running epoch : 33
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0026256131898452417
# mae of all images in validation set is
# 0.019932159580927283
# psnr of all images in validation set is
# 25.807692545943727
# Running epoch : 34
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0025947306446607865
# mae of all images in validation set is
# 0.020116815376364144
# psnr of all images in validation set is
# 25.859077189750693
# Running epoch : 35
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002559211615349435
# mae of all images in validation set is
# 0.01800861087933709
# psnr of all images in validation set is
# 25.918938018116027
# Running epoch : 36
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0025493241692650425
# mae of all images in validation set is
# 0.01927044333101017
# psnr of all images in validation set is
# 25.935749366093503
# Running epoch : 37
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0025254227615804986
# mae of all images in validation set is
# 0.020128295999239227
# psnr of all images in validation set is
# 25.976659095639615
# Running epoch : 38
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0024129193432363845
# mae of all images in validation set is
# 0.019370269060909058
# psnr of all images in validation set is
# 26.17457195029803
# Running epoch : 39
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0023174953009565996
# mae of all images in validation set is
# 0.018971581756785216
# psnr of all images in validation set is
# 26.349811377749162
# Running epoch : 40
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00229623724905129
# mae of all images in validation set is
# 0.018283282178892482
# psnr of all images in validation set is
# 26.389832423059673
# Running epoch : 41
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002441659475931206
# mae of all images in validation set is
# 0.019034936909374783
# psnr of all images in validation set is
# 26.12314904697473
# Running epoch : 42
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018866013676176057
# mae of all images in validation set is
# 0.01636438010248859
# psnr of all images in validation set is
# 27.24319855072445
# Running epoch : 43
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002230847824886838
# mae of all images in validation set is
# 0.017553721752657417
# psnr of all images in validation set is
# 26.515300536811868
# Running epoch : 44
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0019150474551790637
# mae of all images in validation set is
# 0.01600990460442931
# psnr of all images in validation set is
# 27.178204596760118
# Running epoch : 45
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018222443614662014
# mae of all images in validation set is
# 0.015460991286737712
# psnr of all images in validation set is
# 27.393933849259096
# Running epoch : 46
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001879654697006351
# mae of all images in validation set is
# 0.01682611366038036
# psnr of all images in validation set is
# 27.259219257142018
# Running epoch : 47
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017789645704034663
# mae of all images in validation set is
# 0.015469871327340864
# psnr of all images in validation set is
# 27.498327011749232
# Running epoch : 48
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001852396234137326
# mae of all images in validation set is
# 0.015296554116710694
# psnr of all images in validation set is
# 27.322661105841263
# Running epoch : 49
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0021026164361160117
# mae of all images in validation set is
# 0.0184863890539491
# psnr of all images in validation set is
# 26.772399450365818
# Running epoch : 50
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00205455463832137
# mae of all images in validation set is
# 0.017986468881394997
# psnr of all images in validation set is
# 26.87282304727763
# Running epoch : 51
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016864467611498752
# mae of all images in validation set is
# 0.015149704140235493
# psnr of all images in validation set is
# 27.730273643495398
# Running epoch : 52
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017205636139687723
# mae of all images in validation set is
# 0.015479988230060438
# psnr of all images in validation set is
# 27.64329265684797
# Running epoch : 53
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001597808895754782
# mae of all images in validation set is
# 0.014754692354354766
# psnr of all images in validation set is
# 27.96475165248726
# Running epoch : 54
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001636423898346277
# mae of all images in validation set is
# 0.014955202294241167
# psnr of all images in validation set is
# 27.861041866876413
# Running epoch : 55
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017098926913096044
# mae of all images in validation set is
# 0.014986251053062411
# psnr of all images in validation set is
# 27.670311440139468
# Running epoch : 56
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001684265488004736
# mae of all images in validation set is
# 0.015036006745412226
# psnr of all images in validation set is
# 27.73589450313971
# Running epoch : 57
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018102265222526696
# mae of all images in validation set is
# 0.015736743292463055
# psnr of all images in validation set is
# 27.42267076396621
# Running epoch : 58
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0015917580918151238
# mae of all images in validation set is
# 0.013967217488121624
# psnr of all images in validation set is
# 27.98122933691716
# Running epoch : 59
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0015071897477991283
# mae of all images in validation set is
# 0.014277153060614289
# psnr of all images in validation set is
# 28.21832068697568
# Running epoch : 60
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001579662670518318
# mae of all images in validation set is
# 0.014074278446361242
# psnr of all images in validation set is
# 28.014356446744323
# Running epoch : 61
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001997585211324516
# mae of all images in validation set is
# 0.01902439040940334
# psnr of all images in validation set is
# 26.994946858469024
# Running epoch : 62
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0015558780552238514
# mae of all images in validation set is
# 0.014439060656462447
# psnr of all images in validation set is
# 28.080244446334376
# Running epoch : 63
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014767608191964012
# mae of all images in validation set is
# 0.01387812424876369
# psnr of all images in validation set is
# 28.306898386858016
# Running epoch : 64
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014766766295927936
# mae of all images in validation set is
# 0.01359583585929931
# psnr of all images in validation set is
# 28.30714598363922
# Running epoch : 65
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016974486792393274
# mae of all images in validation set is
# 0.01588496236000418
# psnr of all images in validation set is
# 27.702033473332325
# Running epoch : 66
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014370141046836267
# mae of all images in validation set is
# 0.013474749194372903
# psnr of all images in validation set is
# 28.425389691265917
# Running epoch : 67
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012803684684214946
# mae of all images in validation set is
# 0.01321067197581485
# psnr of all images in validation set is
# 28.926650297475007
# Running epoch : 68
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017283596517046924
# mae of all images in validation set is
# 0.015166305079120047
# psnr of all images in validation set is
# 27.62365880781625
# Running epoch : 69
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013233995177366724
# mae of all images in validation set is
# 0.013621081112141659
# psnr of all images in validation set is
# 28.783090279547324
# Running epoch : 70
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013089137683929615
# mae of all images in validation set is
# 0.013341118432793236
# psnr of all images in validation set is
# 28.830889639493826
# Running epoch : 71
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012898905143620928
# mae of all images in validation set is
# 0.01330878929384276
# psnr of all images in validation set is
# 28.894471509614554
# Running epoch : 72
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014730307872741432
# mae of all images in validation set is
# 0.014325193566791449
# psnr of all images in validation set is
# 28.317881760334423
# Running epoch : 73
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014300150882876586
# mae of all images in validation set is
# 0.013596158405912155
# psnr of all images in validation set is
# 28.446593802094124
# Running epoch : 74
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013752315394438316
# mae of all images in validation set is
# 0.013792142782757163
# psnr of all images in validation set is
# 28.616241761338678
# Running epoch : 75
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012052137189933192
# mae of all images in validation set is
# 0.012457249932363228
# psnr of all images in validation set is
# 29.189359333800404
# Running epoch : 76
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014922297576002153
# mae of all images in validation set is
# 0.014364882463420051
# psnr of all images in validation set is
# 28.26164303689197
# Running epoch : 77
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012168798705058765
# mae of all images in validation set is
# 0.012986273161034501
# psnr of all images in validation set is
# 29.147522928886673
# Running epoch : 78
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0011249846262519098
# mae of all images in validation set is
# 0.012422464882233713
# psnr of all images in validation set is
# 29.488534124678033
# Running epoch : 79
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0011331945777952087
# mae of all images in validation set is
# 0.012762550618176641
# psnr of all images in validation set is
# 29.45695512195418
# Running epoch : 80
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0011805581838367828
# mae of all images in validation set is
# 0.01280774160485386
# psnr of all images in validation set is
# 29.279126038444232
# Running epoch : 81
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001154229784224232
# mae of all images in validation set is
# 0.012336240308808854
# psnr of all images in validation set is
# 29.37707723167766
# Running epoch : 82
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010730394051745298
# mae of all images in validation set is
# 0.012102123625787789
# psnr of all images in validation set is
# 29.69384329165806
# Running epoch : 83
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010908602478404516
# mae of all images in validation set is
# 0.0121006662943301
# psnr of all images in validation set is
# 29.622308841314975
# Running epoch : 84
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010971227489494668
# mae of all images in validation set is
# 0.01210548123932817
# psnr of all images in validation set is
# 29.597447797095953
# Running epoch : 85
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012078563647805454
# mae of all images in validation set is
# 0.012896485653958099
# psnr of all images in validation set is
# 29.17984707844112
# Running epoch : 86
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010228313852010949
# mae of all images in validation set is
# 0.011830509768640744
# psnr of all images in validation set is
# 29.90195954276398
# Running epoch : 87
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010813245293937507
# mae of all images in validation set is
# 0.011651185835373943
# psnr of all images in validation set is
# 29.66043945109593
# Running epoch : 88
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0011089941182372157
# mae of all images in validation set is
# 0.012093353525772028
# psnr of all images in validation set is
# 29.550707572087255
# Running epoch : 89
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001076787792392457
# mae of all images in validation set is
# 0.01225142808087582
# psnr of all images in validation set is
# 29.678698767146802
# Running epoch : 90
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0014485647733559382
# mae of all images in validation set is
# 0.01448291849731973
# psnr of all images in validation set is
# 28.39062080313786
# Running epoch : 91
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010749341266014583
# mae of all images in validation set is
# 0.012357654551402164
# psnr of all images in validation set is
# 29.6861814907866
# Running epoch : 92
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010588876386064421
# mae of all images in validation set is
# 0.011593846865294037
# psnr of all images in validation set is
# 29.75150121594261
# Running epoch : 93
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009762551166583206
# mae of all images in validation set is
# 0.011091784785794354
# psnr of all images in validation set is
# 30.104366769244756
# Running epoch : 94
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001071646592464817
# mae of all images in validation set is
# 0.011963626588233904
# psnr of all images in validation set is
# 29.69948412635234
# Running epoch : 95
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010364978412411108
# mae of all images in validation set is
# 0.011727521684608654
# psnr of all images in validation set is
# 29.84431598093082
# Running epoch : 96
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010144778876838949
# mae of all images in validation set is
# 0.01194879956074074
# psnr of all images in validation set is
# 29.93757414733667
# Running epoch : 97
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010255258065310425
# mae of all images in validation set is
# 0.01157765203870683
# psnr of all images in validation set is
# 29.89053406487217
# Running epoch : 98
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0011289707751601103
# mae of all images in validation set is
# 0.01267660090866954
# psnr of all images in validation set is
# 29.473173001928124
# Running epoch : 99
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009224298048613929
# mae of all images in validation set is
# 0.011235992159443235
# psnr of all images in validation set is
# 30.35066672888428
# Running epoch : 100
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009842284532673646
# mae of all images in validation set is
# 0.011406565909936679
# psnr of all images in validation set is
# 30.069040840099348
# Running epoch : 101
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001013890394837041
# mae of all images in validation set is
# 0.012048580131029846
# psnr of all images in validation set is
# 29.940089912455655
# Running epoch : 102
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009525790500225603
# mae of all images in validation set is
# 0.011414825353641722
# psnr of all images in validation set is
# 30.21098974115262
# Running epoch : 103
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009469032073243897
# mae of all images in validation set is
# 0.010922824043007168
# psnr of all images in validation set is
# 30.23694412415232
# Running epoch : 104
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001233529171477758
# mae of all images in validation set is
# 0.012554536139909653
# psnr of all images in validation set is
# 29.088505755118902
# Running epoch : 105
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010495817097900895
# mae of all images in validation set is
# 0.012153864225637044
# psnr of all images in validation set is
# 29.789837460004726
# Running epoch : 106
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009138496868516968
# mae of all images in validation set is
# 0.011046070856210025
# psnr of all images in validation set is
# 30.391252326461743
# Running epoch : 107
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012085014692359544
# mae of all images in validation set is
# 0.014294910063242959
# psnr of all images in validation set is
# 29.17752817262388
# Running epoch : 108
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010013783443466849
# mae of all images in validation set is
# 0.011762320497270542
# psnr of all images in validation set is
# 29.99401804820903
# Running epoch : 109
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009368433955487499
# mae of all images in validation set is
# 0.011408391882504322
# psnr of all images in validation set is
# 30.28333000503092
# Running epoch : 110
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001019819933833065
# mae of all images in validation set is
# 0.01189076716920799
# psnr of all images in validation set is
# 29.91476503381396
# Running epoch : 111
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008973258130826818
# mae of all images in validation set is
# 0.010721732479114232
# psnr of all images in validation set is
# 30.47049838859825
# Running epoch : 112
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008794339166428198
# mae of all images in validation set is
# 0.010880493402230322
# psnr of all images in validation set is
# 30.557967891975736
# Running epoch : 113
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009366521181393787
# mae of all images in validation set is
# 0.011163581213915004
# psnr of all images in validation set is
# 30.284216804311562
# Running epoch : 114
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008680087704913239
# mae of all images in validation set is
# 0.010773786729564697
# psnr of all images in validation set is
# 30.614758866244962
# Running epoch : 115
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008768577209888345
# mae of all images in validation set is
# 0.010781122400666284
# psnr of all images in validation set is
# 30.570708695784
# Running epoch : 116
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008712170197836417
# mae of all images in validation set is
# 0.011171283077323074
# psnr of all images in validation set is
# 30.598736489479673
# Running epoch : 117
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008882165758323184
# mae of all images in validation set is
# 0.010920743779423906
# psnr of all images in validation set is
# 30.514811263150822
# Running epoch : 118
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001063679165446413
# mae of all images in validation set is
# 0.012625076627356712
# psnr of all images in validation set is
# 29.731893473116276
# Running epoch : 119
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010160716832891333
# mae of all images in validation set is
# 0.012264593222558984
# psnr of all images in validation set is
# 29.930756517383898
# Running epoch : 120
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0029025541758734676
# mae of all images in validation set is
# 0.025234773985740793
# psnr of all images in validation set is
# 25.372196654521545
# Running epoch : 121
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013950586902885924
# mae of all images in validation set is
# 0.015285116553392606
# psnr of all images in validation set is
# 28.554075211844268
# Running epoch : 122
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001235814868824115
# mae of all images in validation set is
# 0.012331450893679747
# psnr of all images in validation set is
# 29.080465838346473
# Running epoch : 123
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008823195161125151
# mae of all images in validation set is
# 0.010687503367546538
# psnr of all images in validation set is
# 30.5437411446449
# Running epoch : 124
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000892058199285654
# mae of all images in validation set is
# 0.01064651725345971
# psnr of all images in validation set is
# 30.49606810641723
# Running epoch : 125
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009230186893950574
# mae of all images in validation set is
# 0.010937343232285887
# psnr of all images in validation set is
# 30.347895052373936
# Running epoch : 126
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008787773192271291
# mae of all images in validation set is
# 0.01075205825731648
# psnr of all images in validation set is
# 30.561211605153137
# Running epoch : 127
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000887290906777636
# mae of all images in validation set is
# 0.010706080766128615
# psnr of all images in validation set is
# 30.519339692378843
# Running epoch : 128
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009395788686480848
# mae of all images in validation set is
# 0.011063502347546437
# psnr of all images in validation set is
# 30.27066759170645
# Running epoch : 129
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008602901817019003
# mae of all images in validation set is
# 0.010570443167771556
# psnr of all images in validation set is
# 30.653550335761214
# Running epoch : 130
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008080104830702673
# mae of all images in validation set is
# 0.010291013139262438
# psnr of all images in validation set is
# 30.925830046832893
# Running epoch : 131
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008436572730554082
# mae of all images in validation set is
# 0.010206373062376695
# psnr of all images in validation set is
# 30.738339451397326
# Running epoch : 132
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009469248173125809
# mae of all images in validation set is
# 0.010686561008108173
# psnr of all images in validation set is
# 30.236845011682725
# Running epoch : 133
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008986607082877024
# mae of all images in validation set is
# 0.010653380865844051
# psnr of all images in validation set is
# 30.464042463441594
# Running epoch : 134
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008894659301016363
# mae of all images in validation set is
# 0.010839881814959445
# psnr of all images in validation set is
# 30.508706823773952
# Running epoch : 135
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008348496008978464
# mae of all images in validation set is
# 0.010495285724360238
# psnr of all images in validation set is
# 30.783917561131716
# Running epoch : 136
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010548673949704994
# mae of all images in validation set is
# 0.012297500437485426
# psnr of all images in validation set is
# 29.768021311266352
# Running epoch : 137
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008815487084974223
# mae of all images in validation set is
# 0.01098878641143562
# psnr of all images in validation set is
# 30.547536864874818
# Running epoch : 138
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008500638705819546
# mae of all images in validation set is
# 0.010673049403144817
# psnr of all images in validation set is
# 30.705484418160786
# Running epoch : 139
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008802708814556102
# mae of all images in validation set is
# 0.01087525258016949
# psnr of all images in validation set is
# 30.55383663964813
# Running epoch : 140
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00087030351317039
# mae of all images in validation set is
# 0.010729211740083958
# psnr of all images in validation set is
# 30.603292633495165
# Running epoch : 141
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009459891110470508
# mae of all images in validation set is
# 0.011557758489710744
# psnr of all images in validation set is
# 30.2411386258277
# Running epoch : 142
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002353609015888655
# mae of all images in validation set is
# 0.02204693200494137
# psnr of all images in validation set is
# 26.282656809765076
# Running epoch : 143
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009021863514556763
# mae of all images in validation set is
# 0.011234463324584318
# psnr of all images in validation set is
# 30.447037473251207
# Running epoch : 144
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018284593203787812
# mae of all images in validation set is
# 0.019382204311120935
# psnr of all images in validation set is
# 27.379146974159273
# Running epoch : 145
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009295986508602576
# mae of all images in validation set is
# 0.011032414474618947
# psnr of all images in validation set is
# 30.31704515251045
# Running epoch : 146
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008777788669002956
# mae of all images in validation set is
# 0.010773714835430517
# psnr of all images in validation set is
# 30.566148792885723
# Running epoch : 147
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008841767346090253
# mae of all images in validation set is
# 0.011153301792503826
# psnr of all images in validation set is
# 30.534609168943526
# Running epoch : 148
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002206140177429541
# mae of all images in validation set is
# 0.021677544629876953
# psnr of all images in validation set is
# 26.563668960889366
# Running epoch : 149
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008923368287390613
# mae of all images in validation set is
# 0.01087228701790798
# psnr of all images in validation set is
# 30.494711823383554
# Running epoch : 150
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008153590510529721
# mae of all images in validation set is
# 0.010058816421117684
# psnr of all images in validation set is
# 30.88651103465537
# Running epoch : 151
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018521276864747803
# mae of all images in validation set is
# 0.01964173739214493
# psnr of all images in validation set is
# 27.32329076174672
# Running epoch : 152
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008281683142992755
# mae of all images in validation set is
# 0.010454479504554382
# psnr of all images in validation set is
# 30.81881389612707
# Running epoch : 153
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002053247543094733
# mae of all images in validation set is
# 0.020514523219052186
# psnr of all images in validation set is
# 26.875586881748422
# Running epoch : 154
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009740532858800814
# mae of all images in validation set is
# 0.011868754724502653
# psnr of all images in validation set is
# 30.114172842603143
# Running epoch : 155
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001020031269243888
# mae of all images in validation set is
# 0.012630091678393147
# psnr of all images in validation set is
# 29.913865146577663
# Running epoch : 156
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0021158832925202964
# mae of all images in validation set is
# 0.02095033930229032
# psnr of all images in validation set is
# 26.745082907069154
# Running epoch : 157
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008371702973777757
# mae of all images in validation set is
# 0.010455824540047553
# psnr of all images in validation set is
# 30.77186188734888
# Running epoch : 158
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0020585209630829384
# mae of all images in validation set is
# 0.02065608099652401
# psnr of all images in validation set is
# 26.86444705977699
# Running epoch : 159
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0037264360925655347
# mae of all images in validation set is
# 0.027448142820141762
# psnr of all images in validation set is
# 24.287063224101516
# Running epoch : 160
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009787021317427967
# mae of all images in validation set is
# 0.012066643648089542
# psnr of all images in validation set is
# 30.093494657292446
# Running epoch : 161
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0024217225867467626
# mae of all images in validation set is
# 0.022469590108436847
# psnr of all images in validation set is
# 26.158756076609208
# Running epoch : 162
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0022977348147878718
# mae of all images in validation set is
# 0.021877538519076253
# psnr of all images in validation set is
# 26.387000953692056
# Running epoch : 163
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016818643924176697
# mae of all images in validation set is
# 0.01831307030725346
# psnr of all images in validation set is
# 27.742090239952546
# Running epoch : 164
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010196989115281879
# mae of all images in validation set is
# 0.01296143841838782
# psnr of all images in validation set is
# 29.915280442822088
# Running epoch : 165
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0026329712246602613
# mae of all images in validation set is
# 0.023226706997078104
# psnr of all images in validation set is
# 25.79553887205953
# Running epoch : 166
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002206373875739425
# mae of all images in validation set is
# 0.021385412625365082
# psnr of all images in validation set is
# 26.563208933407143
# Running epoch : 167
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0023316672422008717
# mae of all images in validation set is
# 0.02191172971203968
# psnr of all images in validation set is
# 26.323334286932607
# Running epoch : 168
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001830195900686216
# mae of all images in validation set is
# 0.018691409064069155
# psnr of all images in validation set is
# 27.375024217266542
# Running epoch : 169
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008436991601700815
# mae of all images in validation set is
# 0.01055152992516863
# psnr of all images in validation set is
# 30.738123831953672
# Running epoch : 170
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010195290928695342
# mae of all images in validation set is
# 0.011870217503547602
# psnr of all images in validation set is
# 29.916003768574665
# Running epoch : 171
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0015907688674890819
# mae of all images in validation set is
# 0.017682375883697893
# psnr of all images in validation set is
# 27.98392917063731
# Running epoch : 172
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0026990186312729125
# mae of all images in validation set is
# 0.023351753274908495
# psnr of all images in validation set is
# 25.687941175068076
# Running epoch : 173
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013767807939557134
# mae of all images in validation set is
# 0.015920313417057585
# psnr of all images in validation set is
# 28.611352010311872
# Running epoch : 174
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016194094690621696
# mae of all images in validation set is
# 0.018012343495967288
# psnr of all images in validation set is
# 27.90643325632011
# Running epoch : 175
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016687137345652607
# mae of all images in validation set is
# 0.018505165696441964
# psnr of all images in validation set is
# 27.776181595231595
# Running epoch : 176
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002138434511373014
# mae of all images in validation set is
# 0.02102289823783171
# psnr of all images in validation set is
# 26.699040452831696
# Running epoch : 177
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001573095815551343
# mae of all images in validation set is
# 0.017825574335284453
# psnr of all images in validation set is
# 28.03244824167605
# Running epoch : 178
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010332997866598376
# mae of all images in validation set is
# 0.013036095707717419
# psnr of all images in validation set is
# 29.857736602773386
# Running epoch : 179
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.003252257275964671
# mae of all images in validation set is
# 0.025926339549354003
# psnr of all images in validation set is
# 24.878151060323912
# Running epoch : 180
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008277104209103636
# mae of all images in validation set is
# 0.009975519658445288
# psnr of all images in validation set is
# 30.821215769802297
# Running epoch : 181
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007687166505534498
# mae of all images in validation set is
# 0.009770200319858079
# psnr of all images in validation set is
# 31.142337119251803
# Running epoch : 182
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016047879378852305
# mae of all images in validation set is
# 0.017539531519344686
# psnr of all images in validation set is
# 27.945823486117753
# Running epoch : 183
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0012718394736959873
# mae of all images in validation set is
# 0.015107885951008778
# psnr of all images in validation set is
# 28.95567700077118
# Running epoch : 184
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007517750787069671
# mae of all images in validation set is
# 0.009565452231947753
# psnr of all images in validation set is
# 31.23912075216298
# Running epoch : 185
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008305342562740668
# mae of all images in validation set is
# 0.010298739312157888
# psnr of all images in validation set is
# 30.80642449902559
# Running epoch : 186
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008277526009918315
# mae of all images in validation set is
# 0.010854431329744863
# psnr of all images in validation set is
# 30.82099445919144
# Running epoch : 187
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0030538963377412997
# mae of all images in validation set is
# 0.0246251627672773
# psnr of all images in validation set is
# 25.15145708835266
# Running epoch : 188
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008218955695743479
# mae of all images in validation set is
# 0.01037709937539755
# psnr of all images in validation set is
# 30.851833606093454
# Running epoch : 189
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010578993769383245
# mae of all images in validation set is
# 0.012745849262308432
# psnr of all images in validation set is
# 29.7555563865117
# Running epoch : 190
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001174982057168224
# mae of all images in validation set is
# 0.014047029935599626
# psnr of all images in validation set is
# 29.299687653346517
# Running epoch : 191
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008235819512752284
# mae of all images in validation set is
# 0.010539055351560326
# psnr of all images in validation set is
# 30.84293179474432
# Running epoch : 192
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007028624938909696
# mae of all images in validation set is
# 0.008944812430221409
# psnr of all images in validation set is
# 31.53129630862888
# Running epoch : 193
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017774570080909967
# mae of all images in validation set is
# 0.018365977862322753
# psnr of all images in validation set is
# 27.502008948877304
# Running epoch : 194
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000907162932454999
# mae of all images in validation set is
# 0.01118576878620466
# psnr of all images in validation set is
# 30.423147037765013
# Running epoch : 195
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007257745466733862
# mae of all images in validation set is
# 0.009132275212064035
# psnr of all images in validation set is
# 31.391982668231606
# Running epoch : 196
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007455179653240381
# mae of all images in validation set is
# 0.009328565812855506
# psnr of all images in validation set is
# 31.275418865542647
# Running epoch : 197
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007499806667187914
# mae of all images in validation set is
# 0.009802107310461227
# psnr of all images in validation set is
# 31.24949931869056
# Running epoch : 198
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00266952236927982
# mae of all images in validation set is
# 0.02293152237417607
# psnr of all images in validation set is
# 25.73566435617428
# Running epoch : 199
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0016855484644893361
# mae of all images in validation set is
# 0.01878896799748167
# psnr of all images in validation set is
# 27.732587557163168
# Running epoch : 200
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007681183505171459
# mae of all images in validation set is
# 0.009825223903527391
# psnr of all images in validation set is
# 31.145718593739762
# Running epoch : 201
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0013233332197795317
# mae of all images in validation set is
# 0.015545197364633934
# psnr of all images in validation set is
# 28.783307852228887
# Running epoch : 202
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008482041834135265
# mae of all images in validation set is
# 0.01060826593982572
# psnr of all images in validation set is
# 30.71499589894548
# Running epoch : 203
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0017480009906543372
# mae of all images in validation set is
# 0.01791799681923465
# psnr of all images in validation set is
# 27.574583255714153
# Running epoch : 204
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007703118315113736
# mae of all images in validation set is
# 0.009814324134123212
# psnr of all images in validation set is
# 31.133334315940214
# Running epoch : 205
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007621019163355879
# mae of all images in validation set is
# 0.009705296028857672
# psnr of all images in validation set is
# 31.179869463212157
# Running epoch : 206
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008594271467079655
# mae of all images in validation set is
# 0.010925449304628488
# psnr of all images in validation set is
# 30.657909323844063
# Running epoch : 207
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009056035374938428
# mae of all images in validation set is
# 0.011082671097260603
# psnr of all images in validation set is
# 30.4306188969925
# Running epoch : 208
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010508403284004272
# mae of all images in validation set is
# 0.013135781907472709
# psnr of all images in validation set is
# 29.784632685223514
# Running epoch : 209
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008396248718775115
# mae of all images in validation set is
# 0.010544079015188959
# psnr of all images in validation set is
# 30.759147049643765
# Running epoch : 210
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.002991827210183076
# mae of all images in validation set is
# 0.023754893683624052
# psnr of all images in validation set is
# 25.24063492301879
# Running epoch : 211
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010698612743822763
# mae of all images in validation set is
# 0.013485121840185991
# psnr of all images in validation set is
# 29.706725322925273
# Running epoch : 212
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0021681292982264405
# mae of all images in validation set is
# 0.021199702034913427
# psnr of all images in validation set is
# 26.63914821842208
# Running epoch : 213
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000750033204238054
# mae of all images in validation set is
# 0.009783346224500623
# psnr of all images in validation set is
# 31.249195098107542
# Running epoch : 214
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001343606929030422
# mae of all images in validation set is
# 0.01624858073527356
# psnr of all images in validation set is
# 28.717277651519588
# Running epoch : 215
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007160936985418181
# mae of all images in validation set is
# 0.009188359141330517
# psnr of all images in validation set is
# 31.45030147947312
# Running epoch : 216
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007568508956320267
# mae of all images in validation set is
# 0.009647086826592932
# psnr of all images in validation set is
# 31.20989670806942
# Running epoch : 217
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018746351706128606
# mae of all images in validation set is
# 0.019519094377813528
# psnr of all images in validation set is
# 27.27083239299614
# Running epoch : 218
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007171261184765525
# mae of all images in validation set is
# 0.009249268323055218
# psnr of all images in validation set is
# 31.44404459755044
# Running epoch : 219
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008223649737520415
# mae of all images in validation set is
# 0.010538052855715884
# psnr of all images in validation set is
# 30.849353954671784
# Running epoch : 220
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007078575461773814
# mae of all images in validation set is
# 0.009350686474676424
# psnr of all images in validation set is
# 31.50054133742321
# Running epoch : 221
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0010205563440685002
# mae of all images in validation set is
# 0.013355542135832559
# psnr of all images in validation set is
# 29.911630132482113
# Running epoch : 222
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.001661046793536194
# mae of all images in validation set is
# 0.018625043553772903
# psnr of all images in validation set is
# 27.79618132817536
# Running epoch : 223
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009655957700748614
# mae of all images in validation set is
# 0.012835602321685437
# psnr of all images in validation set is
# 30.152046453932776
# Running epoch : 224
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007065828031205699
# mae of all images in validation set is
# 0.009451912301427313
# psnr of all images in validation set is
# 31.508369366729344
# Running epoch : 225
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006544282449688358
# mae of all images in validation set is
# 0.00886700449332813
# psnr of all images in validation set is
# 31.841379648847305
# Running epoch : 226
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008029515103043353
# mae of all images in validation set is
# 0.010375518609987066
# psnr of all images in validation set is
# 30.953106806778656
# Running epoch : 227
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.00079213517838045
# mae of all images in validation set is
# 0.010044106358115746
# psnr of all images in validation set is
# 31.012006994519155
# Running epoch : 228
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000744963480042314
# mae of all images in validation set is
# 0.00979192958588435
# psnr of all images in validation set is
# 31.278650169226523
# Running epoch : 229
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0008504973440280927
# mae of all images in validation set is
# 0.010668883156244586
# psnr of all images in validation set is
# 30.703270382839158
# Running epoch : 230
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0025672789978164893
# mae of all images in validation set is
# 0.023123770325342845
# psnr of all images in validation set is
# 25.905269320188445
# Running epoch : 231
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007327537717331421
# mae of all images in validation set is
# 0.009395498585581107
# psnr of all images in validation set is
# 31.35041937422212
# Running epoch : 232
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007594968429757965
# mae of all images in validation set is
# 0.009993930391716645
# psnr of all images in validation set is
# 31.194740270428547
# Running epoch : 233
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007658073901223717
# mae of all images in validation set is
# 0.009772244472651818
# psnr of all images in validation set is
# 31.15880446980391
# Running epoch : 234
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0018170380861550553
# mae of all images in validation set is
# 0.01924188097688216
# psnr of all images in validation set is
# 27.406359695364202
# Running epoch : 235
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006971154223597732
# mae of all images in validation set is
# 0.009102976427328257
# psnr of all images in validation set is
# 31.56695309213488
# Running epoch : 236
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0009321871333474218
# mae of all images in validation set is
# 0.012350908866614649
# psnr of all images in validation set is
# 30.304968957767212
# Running epoch : 237
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0038333052292751947
# mae of all images in validation set is
# 0.028232281327926483
# psnr of all images in validation set is
# 24.164265984048626
# Running epoch : 238
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007245707839111137
# mae of all images in validation set is
# 0.009132284613875417
# psnr of all images in validation set is
# 31.399191815380163
# Running epoch : 239
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006889788138005584
# mae of all images in validation set is
# 0.008901517081255993
# psnr of all images in validation set is
# 31.617941325059814
# Running epoch : 240
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007325936293807023
# mae of all images in validation set is
# 0.009527384246342533
# psnr of all images in validation set is
# 31.35136862271033
# Running epoch : 241
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007425332210930739
# mae of all images in validation set is
# 0.0092033114957213
# psnr of all images in validation set is
# 31.292841111492685
# Running epoch : 242
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007006762508434007
# mae of all images in validation set is
# 0.008924540623075392
# psnr of all images in validation set is
# 31.544826025042205
# Running epoch : 243
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006800251518668863
# mae of all images in validation set is
# 0.008752616143450244
# psnr of all images in validation set is
# 31.674750238893708
# Running epoch : 244
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006942160283413792
# mae of all images in validation set is
# 0.008957738378079703
# psnr of all images in validation set is
# 31.585053633816116
# Running epoch : 245
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0007857371294457319
# mae of all images in validation set is
# 0.010014538411247598
# psnr of all images in validation set is
# 31.04722724095272
# Running epoch : 246
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000702466123132684
# mae of all images in validation set is
# 0.009232687022163176
# psnr of all images in validation set is
# 31.533746150403836
# Running epoch : 247
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006882483531170878
# mae of all images in validation set is
# 0.008921036223937522
# psnr of all images in validation set is
# 31.622548191398874
# Running epoch : 248
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.000710700437145598
# mae of all images in validation set is
# 0.00948219844837926
# psnr of all images in validation set is
# 31.483134174267683
# Running epoch : 249
# The shape is
# (11, 480, 480, 3)
# (11, 480, 480)
# mse of all images in validation set is
# 0.0006855573778173587
# mae of all images in validation set is
# 0.009120129643772255
# psnr of all images in validation set is
# 31.63956191017956
# read both T1_test and T2_test
# made all the augmented images
# mse of all images in test set is
# 0.0010529217928472502
# mae of all images in test set is
# 0.010494757084088521
# psnr of all images in test set is
# 29.776038854111412
# Shape of T1_test_data
# (36, 480, 480, 3)
# <class 'numpy.ndarray'>
# Shape of temp
# (1440, 1440)
# <class 'numpy.ndarray'>

# %%
# !zip -r /content/result_files_HGSR.zip /content/AllResults_HGSR
# Out:
#   adding: content/AllResults_HGSR/ (stored 0%)
#   adding: content/AllResults_HGSR/recon_epoch244.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch147.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch346.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch310.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch86.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch340.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch95.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch214.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch102.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch317.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch283.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch279.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch232.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch238.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch53.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch99.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch28.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch339.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch237.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch0.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch36.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch189.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch61.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch324.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch18.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch236.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch197.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch41.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch77.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch153.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch322.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch202.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch113.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch201.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch93.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch26.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch195.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch278.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch196.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch182.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch180.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch162.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch249.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch48.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch127.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch284.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch101.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch258.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch63.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch123.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch348.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch62.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch323.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch194.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch210.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch304.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch220.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch146.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch2.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch98.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch13.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch49.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch134.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch121.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch116.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch311.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch35.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch118.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch173.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch256.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch56.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch141.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch24.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch130.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch155.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch336.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch31.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch206.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch274.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch57.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch30.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch257.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch175.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch103.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch15.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch281.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch129.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch294.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch138.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch282.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch89.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch207.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch33.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch22.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch68.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch217.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch54.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch84.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch131.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch166.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch302.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch79.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch235.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch213.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch64.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch29.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch299.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch11.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch46.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch295.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch229.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch268.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch115.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch250.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch21.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch44.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch154.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch338.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch255.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch92.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch215.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch288.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch243.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch88.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch270.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch74.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch97.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch245.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch183.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch233.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch312.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch169.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch40.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch168.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch75.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch287.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch70.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch72.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch315.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch290.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch308.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch332.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/test.jpg (deflated 11%)
#   adding: content/AllResults_HGSR/recon_epoch265.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch112.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch239.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch114.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch289.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch171.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch149.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch184.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch328.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch251.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch132.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch277.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch136.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch219.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch291.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch225.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch45.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch58.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch222.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch106.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch190.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch178.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch59.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch305.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch321.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch6.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch329.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch224.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch326.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch81.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch199.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch120.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch67.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch191.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch165.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch341.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch34.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch137.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch226.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch158.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch159.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch144.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch307.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch87.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch253.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch126.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch337.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch163.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch139.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch80.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch152.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch275.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch151.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch264.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch142.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch252.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch298.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch52.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch148.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch319.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch94.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch76.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch160.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch23.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch125.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch218.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch248.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch335.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch198.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch117.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch60.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch176.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch109.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch5.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch124.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch104.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch296.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch254.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch259.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch186.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch316.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch12.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch143.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch9.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch300.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch285.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch7.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch4.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch16.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch260.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch211.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch133.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch228.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch38.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch140.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch204.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch90.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch96.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch128.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch170.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch181.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch66.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch301.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch157.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch209.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch50.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch227.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch108.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch107.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch347.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch179.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch349.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch292.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch17.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch135.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch27.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch280.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch43.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch145.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch314.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch174.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch342.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch25.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch161.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch39.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch276.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch345.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch71.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch293.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch65.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch110.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch223.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch327.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch221.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch172.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch91.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch231.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch325.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch267.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch200.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch343.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch216.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch192.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch14.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch246.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch334.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch193.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch303.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch167.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch8.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch73.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch230.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch10.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch19.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch32.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch330.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch37.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch85.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch150.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch286.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch273.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch42.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch212.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch261.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch185.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch78.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch188.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch331.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch269.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch187.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch333.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch344.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch1.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch82.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch208.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch241.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch247.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch297.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch205.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch263.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch164.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch271.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch177.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch20.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch262.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch55.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch111.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch119.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch242.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch309.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch266.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch272.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch3.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch47.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch69.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch51.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch320.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch306.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch203.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch240.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch318.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch100.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch105.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch313.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch122.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch234.jpg (deflated 6%)
#   adding: content/AllResults_HGSR/recon_epoch83.jpg (deflated 7%)
#   adding: content/AllResults_HGSR/recon_epoch156.jpg (deflated 7%)
